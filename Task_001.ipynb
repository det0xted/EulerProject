# %% [markdown]
# ![image.png](attachment:e823b80f-273a-4e1a-bf3a-9bd6b2aaf227.png)

# %%
summa = 0

for i in range(1, 1000):
    if i % 3 == 0 or i % 5 == 0:
        summa += i

print("Задача 1:", summa)
