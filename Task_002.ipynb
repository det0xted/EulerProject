# %% [markdown]
# ![image.png](attachment:0cc10419-18d6-4dba-be7f-577fa45ed77f.png)

# %%
a, b = 1, 2
total = 0

while a <= 4_000_000:
    if a % 2 == 0:
        total += a
    a, b = b, a + b

print(total)
# Out:
# 4613732
